# %% [markdown]
# Loading the enviroment Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# Importing the required libraries

# %%
from langchain.tools import tool  # for making tools
from bs4 import BeautifulSoup  # web scrapping
from tavily import TavilyClient  # web search
import requests  # help in search 
import os  # help in search
from rich import print # Asthatics

# %% [markdown]
# ---

# %% [markdown]
# ### Procedure for making  Tool : 1
# We search information in Tavily and Extract 5 relevant links from the search results.

# %%
tavily_client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))

@tool
def web_search(query : str) -> str:
    """Search the web for recent and reliable information on a topic . Returns Titles , URLs and snippets."""
    results = tavily_client.search(query=query,max_results=5)

    out = []

    for r in results['results']:
        out.append(
            f"Title: {r['title']}\nURL: {r['url']}\nSnippet: {r['content'][:300]}\n"
        )
    
    return "\n----\n".join(out)

# %%
# Checking  Above tool 
tavily_result = web_search.invoke("Jantar mantar protest")
print(tavily_result)
print(tavily_result.results)
# Out:
# {
#     'query': 'Jantar mantar protest',
#     'follow_up_questions': None,
#     'answer': None,
#     'images': [],
#     'results': [
#         {
#             'url': 'https://www.instagram.com/p/DbACjLZAb7X',
#             'title': 'Protestors gather at the Jantar Mantar, in Delhi ...',
#             'content': "May be an image of one or more people, people standing, flag and text. Protestors gather at
# the Jantar Mantar, in Delhi, as Cockroach Janta Party aims march to Parliament on July 20, 2026, to press for
# education reforms. Meanwhile, no permission has been granted for the march planned by the CJP to Parliament on July
# 20, when both houses will convene for the Monsoon Session, potentially setting up a showdown between the massive
# crowd and the heavy security arrangements expected to meet them in the morning. Security personnel with riot guns
# have been deployed in the national capital, prompting the CJP to issue a call for more people to arrive at the
# site. May be an image of one or more people and text that says 'ΤΗ Thousands gather at Jantar Mantar despite heavy
# security'. May be an image of one or more people and text that says 'TH 而 A 限間間 Delhi Police on high alert
# ahead of CJP's 'Chalo Sansad' march'.",
#             'score': 0.82895297,
#             'raw_content': None
#         },
#         {
#             'url': 'https://www.bbc.com/news/articles/cly0ey5y10qo',
#             'title': "Why India's cockroach protesters are still on the streets in ...",
#             'content': '# Why India\'s cockroach protesters are still on the streets in over 40C heat. Getty Images
# A Cockroach Janta Party (CJP) supporter during a protest over alleged irregularities in the country\'s major
# examinations on June 6, 2026 in New Delhi, India. Delhi\'s Jantar Mantar - an 18th century astronomical observatory
# and the Indian capital\'s best-known protest site - is heaving with hundreds of students, young professionals and
# activists who have camped here day and night for the past 10 days. They are demanding the resignation of Education
# Minister Dharmendra Pradhan after a key entrance exam for aspiring doctors - called the National Eligibility cum
# Entrance Test (Undergraduate) or NEET-UG - was cancelled in early May following a paper leak. "I had just come back
# from the gym and was playing FIFA on my PS5 when I saw the chief justice\'s comment," he told the BBC at the
# protest ground.',
#             'score': 0.81133276,
#             'raw_content': None
#         },
#         {
#             'url': 'https://www.youtube.com/watch?v=l6Tqf6yybHo',
#             'title': 'LIVE From Jantar Mantar | CJP Protest LIVE | Protestors ...',
#             'content': "LIVE From Jantar Mantar | CJP Protest LIVE | Protestors Gather At Jantar Mantar For CJP
# March LIVE\nNDTV Profit\n1690000 subscribers\n3301 likes\n306077 views\n20 Jul 2026\nFollow live updates from
# Jantar Mantar in New Delhi as CJP supporters gather ahead of reports of a proposed march to Parliament on July 20.
# Security has been increased in the area, while Delhi Police has said permission was not granted for the march.
# Sonam Wangchuk has also appealed for support for the “Chalo Sansad” protest.\n\n#jantarmantar  #sonamwangchuk  #cjp
# #parliamentmarch  #ChaloSansad #delhi  #liveupdates  #delhipolice  #protest  #parliament  #indianews  #breakingnews
# \n\n\n\n\nFor more videos subscribe to our channel: https://www.youtube.com/@NDTVProfitIndia\nVisit NDTV Profit for
# more news: https://www.ndtvprofit.com/\nDon't enter the stock market unaware. Read all Research Reports here:
# https://www.ndtvprofit.com/research-reports\n\nFollow NDTV Profit here\nTwitter:
# https://twitter.com/NDTVProfitIndia , https://twitter.com/NDTVProfit\nLinkedIn:
# https://www.linkedin.com/company/ndtvprofit\nInstagram: https://www.instagram.com/ndtvprofit/\nFacebook:
# https://www.facebook.com/NDTVProfit/\n\n",
#             'score': 0.78886026,
#             'raw_content': None
#         },
#         {
#             'url': 'https://www.youtube.com/watch?v=BhuBQd080Lo',
#             'title': 'CJP Protest LIVE | Live From Jantar Mantar | Supporters Gather At ...',
#             'content': "CJP Protest LIVE | Live From Jantar Mantar | Supporters Gather At Jantar Mantar For CJP
# March LIVE\nNDTV Profit\n1690000 subscribers\n12323 likes\n585255 views\n20 Jul 2026\nFollow live updates from
# Jantar Mantar in New Delhi as CJP supporters gather ahead of reports of a proposed march to Parliament on July 20.
# Security has been increased in the area, while Delhi Police has said permission was not granted for the march.
# Sonam Wangchuk has also appealed for support for the “Chalo Sansad” protest.\n\n#jantarmantar  #sonamwangchuk  #cjp
# #parliamentmarch  #ChaloSansad #delhi  #liveupdates  #delhipolice  #protest  #parliament  #indianews  #breakingnews
# \n\n\n\n\n\nFor more videos subscribe to our channel: https://www.youtube.com/@NDTVProfitIndia\nVisit NDTV Profit
# for more news: https://www.ndtvprofit.com/\nDon't enter the stock market unaware. Read all Research Reports here:
# https://www.ndtvprofit.com/research-reports\n\nFollow NDTV Profit here\nTwitter:
# https://twitter.com/NDTVProfitIndia , https://twitter.com/NDTVProfit\nLinkedIn:
# https://www.linkedin.com/company/ndtvprofit\nInstagram: https://www.instagram.com/ndtvprofit/\nFacebook:
# https://www.facebook.com/NDTVProfit/\n\n",
#             'score': 0.75442725,
#             'raw_content': None
#         },
#         {
#             'url': 'https://www.youtube.com/watch?v=U1zNOBkMpl4',
#             'title': 'Jantar Mantar Protest LIVE Updates | CJP Supporters Clash ...',
#             'content': "Jantar Mantar Protest LIVE Updates | CJP Supporters Clash With Police | Parliament News
# Live Today\nNDTV Profit\n1690000 subscribers\n219 likes\n19223 views\n20 Jul 2026\nWatch LIVE updates from Jantar
# Mantar as thousands of CJP supporters gather for the proposed Parliament march amid massive security deployment
# across central Delhi. Stay tuned for the latest visuals, police action, crowd movement, barricades, political
# reactions, and all major developments from the protest site.\n\nDelhi Police have deployed heavy security around
# Parliament and key routes, while protesters continue to gather despite restrictions. Follow every major update,
# speeches, clashes (if any), detentions, traffic advisories, and breaking news from the ground. Reports also
# indicate talks between CJP representatives and the government as the situation evolves.\n\nStay with us for
# uninterrupted LIVE coverage.\n\n#JantarMantar #CJPProtest #ParliamentLIVE #DelhiProtest #BreakingNews #DelhiPolice
# #IndiaNews #LiveUpdates #MonsoonSession #Politics \n\nFor more videos subscribe to our channel:
# https://www.youtube.com/@NDTVProfitIndia\nVisit NDTV Profit for more news: https://www.ndtvprofit.com/\nDon't enter
# the stock market unaware. Read all Research Reports here: https://www.ndtvprofit.com/research-reports\n\nFollow
# NDTV Profit here\nTwitter: https://twitter.com/NDTVProfitIndia , https://twitter.com/NDTVProfit\nLinkedIn:
# https://www.linkedin.com/company/ndtvprofit\nInstagram: https://www.instagram.com/ndtvprofit/\nFacebook:
# https://www.facebook.com/NDTVProfit/\n\n",
#             'score': 0.7445268,
#             'raw_content': None
#         }
#     ],
#     'response_time': 0.8,
#     'request_id': 'bc8a6448-4343-473c-8dc0-55e1f947348b'
# }

# %%
# Playing with the output format
print(tavily_result['results'][0])

# More specific
print(tavily_result['results'][0]['url'])
print(tavily_result['results'][0]['title'])
print(tavily_result['results'][0]['content'])
# Out:
# {
#     'url': 'https://www.instagram.com/p/DbACjLZAb7X',
#     'title': 'Protestors gather at the Jantar Mantar, in Delhi ...',
#     'content': "May be an image of one or more people, people standing, flag and text. Protestors gather at the
# Jantar Mantar, in Delhi, as Cockroach Janta Party aims march to Parliament on July 20, 2026, to press for education
# reforms. Meanwhile, no permission has been granted for the march planned by the CJP to Parliament on July 20, when
# both houses will convene for the Monsoon Session, potentially setting up a showdown between the massive crowd and
# the heavy security arrangements expected to meet them in the morning. Security personnel with riot guns have been
# deployed in the national capital, prompting the CJP to issue a call for more people to arrive at the site. May be
# an image of one or more people and text that says 'ΤΗ Thousands gather at Jantar Mantar despite heavy security'.
# May be an image of one or more people and text that says 'TH 而 A 限間間 Delhi Police on high alert ahead of CJP's
# 'Chalo Sansad' march'.",
#     'score': 0.82895297,
#     'raw_content': None
# }
# https://www.instagram.com/p/DbACjLZAb7X
# Protestors gather at the Jantar Mantar, in Delhi ...
# May be an image of one or more people, people standing, flag and text. Protestors gather at the Jantar Mantar, in
# Delhi, as Cockroach Janta Party aims march to Parliament on July 20, 2026, to press for education reforms.
# Meanwhile, no permission has been granted for the march planned by the CJP to Parliament on July 20, when both
# houses will convene for the Monsoon Session, potentially setting up a showdown between the massive crowd and the
# heavy security arrangements expected to meet them in the morning. Security personnel with riot guns have been
# deployed in the national capital, prompting the CJP to issue a call for more people to arrive at the site. May be
# an image of one or more people and text that says 'ΤΗ Thousands gather at Jantar Mantar despite heavy security'.
# May be an image of one or more people and text that says 'TH 而 A 限間間 Delhi Police on high alert ahead of CJP's
# 'Chalo Sansad' march'.

# %% [markdown]
# ---

# %% [markdown]
# ### Procedure for making  Tool : 2
#
# As the tavily give little bit content based on  the link, we will use link and the beautiful soup to extract the content of the link
#
# I use AI to make scrapper as i dont know to use beautiful soup. Not Bad :)

# %%
@tool
def scrape_url(url: str) -> str:
    """Scrape and return clean text content from a given URL for deeper reading."""
    try:
        resp = requests.get(url, timeout=8, headers={"User-Agent": "Mozilla/5.0"})
        soup = BeautifulSoup(resp.text, "html.parser")
        for tag in soup(["script", "style", "nav", "footer"]):
            tag.decompose()
        return soup.get_text(separator=" ", strip=True)[:3000]
    except Exception as e:
        return f"Could not scrape URL: {str(e)}"

# %%
# Checking Tool
scrap_result = scrape_url.invoke("https://www.bbc.com/news/articles/cly0ey5y10qo")
print(scrap_result)
# Out:
# CJP's Abhijeet Dipke: Why India's cockroach protesters are still on the streets in over 40C heat Skip to content
# British Broadcasting Corporation Home News US & Canada UK UK Politics England N. Ireland N. Ireland Politics
# Scotland Scotland Politics Wales Wales Politics Africa Asia China India Australia Europe Latin America Middle East
# In Pictures BBC InDepth BBC Verify Football 2026 Sport Business World of Business Technology of Business NYSE
# Opening Bell Technology Artificial Intelligence Intelligence Revolution AI v the Mind Tech Now Health Culture Film
# & TV Music Art & Design Style Books Entertainment News Arts Arts in Motion Travel Destinations Africa Antarctica
# Asia Australia and Pacific Caribbean & Bermuda Central America Europe Middle East North America South America
# World’s Table Culture & Experiences Adventures The SpeciaList Earth Science Natural Wonders Climate Solutions
# Sustainable Business Green Living Audio Podcast Categories Radio Audio FAQs Video BBC Maestro Discover the World
# Live Live News Live Sport Site search Home News Sport Football 2026 Business Technology Health Culture Arts Travel
# Earth Audio Video Live Weather Newsletters Why India's cockroach protesters are still on the streets in over 40C
# heat 30 June 2026 Share Save Add as preferred on Google Geeta Pandey BBC Correspondent, Delhi Getty Images Some
# protesters have been turning up dressed as a cockroach Delhi's Jantar Mantar - an 18th century astronomical
# observatory and the Indian capital's best-known protest site - is heaving with hundreds of students, young
# professionals and activists who have camped here day and night for the past 10 days. A harsh sun beats overhead and
# temperatures hover above 40C. Young men and women stand around in groups; some sit, while others even sleep on the
# baking-hot road, hemmed in by heavy, yellow, metal barricades erected by Delhi police to contain the crowd. As
# protest leaders take turns at the microphone, the crowd chants slogans and sings Bollywood songs of rebellion under
# the watchful gaze of police and paramilitary personnel. The protesters, who call themselves "cockroaches", belong
# to an online satirical movement called the Cockroach Janta Party (CJP). They are demanding the resignation of
# Education Minister Dharmendra Pradhan after a key entrance exam for aspiring doctors - called the National
# Eligibility cum Entrance Test (Undergraduate) or NEET-UG - was cancelled in early May following a paper leak. They
# say he must take moral responsibility for the leak and quit. On Sunday, the protests intensified after Sonam
# Wangchuk, a well-known climate activist from a remote Himalayan region, joined the protesters and began an
# indefinite hunger-strike. CJP emerged in mid-May after Chief Justice of India Surya Kant triggered outrage by
# likening some unemployed young people turning to journalism and activism to "cockroaches" and "parasites". The
# judge later said he was referring to people with "fake and bogus degrees", not young people in g

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Tool Making Process Is Done
#
# Now we will use the tools to make a agent which can search and extract the content of the link and give us the answer of our query.

# %% [markdown]
# Libraries required for making an agent

# %%
from langchain.agents import create_agent
from langchain_mistralai import ChatMistralAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
#model setup 
llm = ChatMistralAI(model = "mistral-small-2506",temperature=0)

# %%
# Making  search Agent 
def build_search_agent():
    return create_agent(
        model = llm,
        tools= [web_search]
    )

# %%
# Making Web scrapper agent
def build_reader_agent():
    return create_agent(
        model = llm,
        tools = [scrape_url]
    )

# %% [markdown]
# ### Now we create a writer

# %%
writer_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert research writer. Write clear, structured and insightful reports."),
    ("human", """Write a detailed research report on the topic below.

Topic: {topic}

Research Gathered:
{research}

Structure the report as:
- Introduction
- Key Findings (minimum 3 well-explained points)
- Conclusion
- Sources (list all URLs found in the research)

Be detailed, factual and professional."""),
])

# %% [markdown]
# #### Creating the writer Pipeline/chain

# %%
# Writer Chain

writer_chain = writer_prompt | llm | StrOutputParser() # we use parser for formatted/beautiful output

# So when we invoke the writer_chain , we have to pass 2 parameters : - topic(topic we give ) and research(partial+deep research)

# %% [markdown]
# ---

# %% [markdown]
# ### Now we will make a Critic pipeline that will review the result generated by the writer_chain

# %%
# Critic Prompt

critic_prompt = ChatPromptTemplate.from_messages([
     ("system", "You are a sharp and constructive research critic. Be honest and specific."),
    ("human", """Review the research report below and evaluate it strictly.

Report:
{report}

Respond in this exact format:

Score: X/10

Strengths:
- ...
- ...

Areas to Improve:
- ...
- ...

One line verdict:
..."""),
])

# %%
# Critic pipeline
critic_chain = critic_prompt | llm | StrOutputParser()

# when we invoke it we provide it the input of writer_chain

# %% [markdown]
# ## Agent Making Process Is Done
#
# ---
# ---
# ---

# %% [markdown]
# ### Now we will create a final pipeling that will call agents in proper manner and use the writer and critic to generate the final answer of the query.
#
# NOTE: We can also use a shared storage to store the intermediate results of the agents and use them in the final pipeline.

# %%
from langchain_core.messages import HumanMessage



def run_research_pipeline(topic : str) -> dict:

    shared_storage = {}

    #search agent working 
    print("\n"+" ="*50)
    print("step 1 - search agent is working ...")
    print("="*50)


    # Calling the 1 agent : That use tavily and do partial Search
    search_agent = build_search_agent()
    search_result = search_agent.invoke({
        "messages": [HumanMessage(content=f"Find recent, reliable and detailed information about: {topic}")]
    })
    shared_storage["search_results"] = search_result['messages'][-1].content

    #print("\n search result ",shared_storage['search_results'])




    # Calling the 2 agent : That use deepResearch using Beautifulsoapp scrapping
    print("\n"+" ="*50)
    print("step 2 - Reader agent is scraping top resources ...")
    print("="*50)

    reader_agent = build_reader_agent()
    reader_result = reader_agent.invoke({
    "messages": [HumanMessage(content= 
            f"Based on the following search results about '{topic}', "
            f"pick the most relevant URL and scrape it for deeper content.\n\n"
            f"Search Results:\n{shared_storage['search_results'][:800]}"
            )]
    })

    shared_storage["scrapped_content"] = reader_result['messages'][-1].content

    #print("\nscraped content: \n", shared_storage['scraped_content'])


    # Now we need a structured Output based on all the information Scrapped

    print("\n"+" ="*50)
    print("step 3 - Writer is drafting the report ...")
    print("="*50)

    research_combined = (
        f"SEARCH RESULTS : \n {shared_storage['search_results']} \n\n"
        f"DETAILED SCRAPED CONTENT : \n {shared_storage['scrapped_content']}"
    )

    writer_report = writer_chain.invoke({
        "topic":topic,
        "research":research_combined
    })

    shared_storage["report"] = writer_report

    #print("\n Final Report\n",shared_storage['report'])

   


    #critic report based on the report

    print("\n"+" ="*50)
    print("step 4 - critic is reviewing the report ")
    print("="*50)

    shared_storage["feedback"] = critic_chain.invoke({
        "report":shared_storage['report']
    })

    #print("\n critic report \n", shared_storage['feedback'])

    return shared_storage

# %%
if __name__ == "__main__":
    topic = "Protest on jantar Mantar"
    final_result = run_research_pipeline(topic)
# Out:
#  = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# step 1 - search agent is working ...
# ==================================================
#  = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# step 2 - Reader agent is scraping top resources ...
# ==================================================
#  = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# step 3 - Writer is drafting the report ...
# ==================================================
#  = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# step 4 - critic is reviewing the report
# ==================================================

# %% [markdown]
# Now we have a final Report

# %%
print("Partial Search\n")
print(final_result["search_results"])


print("Deep  Research\n")
print(final_result["scrapped_content"])


print("Report By Writer\n")
print(final_result["report"])


print("What Critic Says-\n")
print(final_result["feedback"])
# Out:
# Partial Search
# Jantar Mantar, a historic monument in New Delhi, India, has been a significant site for protests and demonstrations
# for many years. It is a popular venue for various groups to voice their concerns and demands to the government.
# Here are some recent and detailed updates on protests at Jantar Mantar:
#
# 1. **Delhi Protest LIVE: CHALO SANSAD LIVE From Jantar Mantar**
#    - **Date**: July 20, 2026
#    - **Details**: This protest was led by Sonam Wangchuk and focused on issues related to the NEET exam. Thousands
# of supporters gathered at Jantar Mantar and marched towards the Parliament. The event was covered live by
# CNBC-TV18, providing real-time updates and coverage of the protest. [Read
# more](https://www.youtube.com/watch?v=eHSVzn5raLw)
#
# 2. **CJP Protest LIVE | Live From Jantar Mantar**
#    - **Date**: July 20, 2026
#    - **Details**: Supporters of the Cockroach Janta Party (CJP) gathered at Jantar Mantar for a protest march to
# the Parliament. The protest was aimed at addressing alleged irregularities in the NEET exam. NDTV Profit provided
# live coverage of the event, highlighting the gathering and subsequent march. [Read
# more](https://www.youtube.com/watch?v=BhuBQd080Lo)
#
# 3. **High Drama at Jantar Mantar as Protesters Clash With Police**
#    - **Date**: July 13, 2023
#    - **Details**: Thousands of supporters of the Cockroach Janta Party gathered at Jantar Mantar to protest against
# alleged irregularities in the NEET exam. The protest turned chaotic as clashes between protesters and police were
# reported. NDTV covered the high drama and provided detailed updates on the situation. [Read
# more](https://www.ndtv.com/video/high-drama-at-jantar-mantar-as-protesters-clash-with-police-1130203)
#
# 4. **Inside the Jantar Mantar Protest: Why Hundreds Gathered in Delhi**
#    - **Date**: July 19, 2023
#    - **Details**: Thousands of people gathered at Jantar Mantar ahead of the CJP's planned march to Parliament. The
# protest was met with a heavy police presence, and the Delhi Police issued warnings and took precautions to maintain
# order. The Hindu provided an inside look at the protest and the reasons behind the gathering. [Read
# more](https://www.thehindu.com/videos/watch-inside-the-jantar-mantar-protest-why-hundreds-gathered-in-delhi/article
# 71242564.ece)
#
# 5. **Jantar Mantar Protest LIVE Updates | CJP Supporters Clash With Police**
#    - **Date**: July 20, 2026
#    - **Details**: Live updates from Jantar Mantar showed CJP supporters clashing with police during a proposed
# march to Parliament. The event was covered by NDTV Profit, which provided real-time updates and detailed coverage
# of the protest and the security measures in place. [Read more](https://www.youtube.com/watch?v=U1zNOBkMpl4)
#
# These updates provide a comprehensive view of the recent protests at Jantar Mantar, highlighting the issues, the
# scale of the gatherings, and the responses from authorities.
# Deep  Research
# The provided URL leads to a YouTube video, and the content scraped from it is minimal and primarily consists of
# standard YouTube page elements. For more detailed information about the protest, it would be beneficial to look for
# a text-based news article or a detailed report from a news website. Unfortunately, the URL you provided does not
# lead to a text-based article, and thus, I cannot provide deeper content from it.
#
# If you have another URL or need further assistance, please let me know!
# Report By Writer
# **Research Report: Protests at Jantar Mantar**
#
# **Introduction**
#
# Jantar Mantar, a historic monument in New Delhi, India, has long been a significant site for protests and
# demonstrations. Its central location and symbolic importance make it a popular venue for various groups to voice
# their concerns and demands to the government. This report provides a detailed analysis of recent protests at Jantar
# Mantar, focusing on the issues raised, the scale of the gatherings, and the responses from authorities.
#
# **Key Findings**
#
# 1. **Frequent and Large-Scale Protests**
#    - Jantar Mantar has witnessed numerous protests in recent years, with large-scale gatherings addressing a
# variety of issues. For instance, on July 20, 2026, thousands of supporters led by Sonam Wangchuk gathered to
# protest against the NEET exam, demonstrating the monument's continued relevance as a site for public demonstration.
#    - The scale of these protests indicates a high level of public engagement and concern over the issues being
# addressed. The frequent occurrence of such large gatherings underscores the importance of Jantar Mantar as a
# platform for civic expression.
#
# 2. **Diverse Issues and Demands**
#    - Protests at Jantar Mantar cover a wide range of issues, reflecting the diverse concerns of the Indian
# populace. Recent protests have focused on alleged irregularities in the NEET exam, highlighting the public's demand
# for transparency and fairness in educational assessments.
#    - The diversity of issues addressed at Jantar Mantar demonstrates its role as a neutral and accessible space for
# various groups to articulate their grievances. This diversity also underscores the monument's significance as a
# symbol of democratic expression in India.
#
# 3. **Security and Authorities' Response**
#    - The scale and frequency of protests at Jantar Mantar often necessitate a significant police presence to
# maintain order. For example, the July 13, 2023, protest saw clashes between protesters and police, highlighting the
# potential for tension and conflict during such events.
#    - Authorities typically take precautions to manage large gatherings, including issuing warnings and deploying
# security personnel. The response of the authorities to protests at Jantar Mantar is crucial in ensuring the safety
# of participants and the smooth functioning of the demonstration.
#
# **Conclusion**
#
# Jantar Mantar remains a vital site for protests and demonstrations in India, serving as a platform for diverse
# groups to voice their concerns and demands. The frequent and large-scale nature of these protests, coupled with the
# wide range of issues addressed, underscores the monument's significance as a symbol of democratic expression.
# However, the potential for conflict and the need for effective security measures highlight the challenges
# associated with managing such gatherings. As India continues to grapple with various social, political, and
# economic issues, Jantar Mantar is likely to remain a key venue for public demonstration and civic engagement.
#
# **Sources**
#
# 1. [Delhi Protest LIVE: CHALO SANSAD LIVE From Jantar Mantar](https://www.youtube.com/watch?v=eHSVzn5raLw)
# 2. [CJP Protest LIVE | Live From Jantar Mantar](https://www.youtube.com/watch?v=BhuBQd080Lo)
# 3. [High Drama at Jantar Mantar as Protesters Clash With
# Police](https://www.ndtv.com/video/high-drama-at-jantar-mantar-as-protesters-clash-with-police-1130203)
# 4. [Inside the Jantar Mantar Protest: Why Hundreds Gathered in
# Delhi](https://www.thehindu.com/videos/watch-inside-the-jantar-mantar-protest-why-hundreds-gathered-in-delhi/articl
# e71242564.ece)
# 5. [Jantar Mantar Protest LIVE Updates | CJP Supporters Clash With
# Police](https://www.youtube.com/watch?v=U1zNOBkMpl4)
# What Critic Says-
# **Score: 6.5/10**
#
# **Strengths:**
# - The report provides a clear and concise overview of the significance of Jantar Mantar as a site for protests in
# India.
# - It presents key findings in a structured manner, covering the frequency, scale, and diversity of protests, as
# well as the response from authorities.
# - The use of specific examples, such as the July 20, 2026, protest, helps to illustrate the points made in the
# report.
#
# **Areas to Improve:**
# - The report lacks a clear research question or objective, making it difficult to assess the depth and relevance of
# the findings.
# - The sources cited are primarily news articles and videos, which may not provide the most comprehensive or
# academic perspective on the topic. Incorporating scholarly articles, government reports, or interviews with key
# stakeholders could strengthen the analysis.
# - The report does not provide a critical analysis of the issues raised in the protests or the effectiveness of the
# authorities' response. A more nuanced discussion of these aspects would enhance the report's depth and insight.
# - The timeline seems inconsistent, mentioning an event from 2026 while other events are from 2023. This needs to be
# clarified or corrected.
# - The report could benefit from a more structured methodology section, outlining how the data was collected and
# analyzed.
#
# **One line verdict:**
# A good starting point, but needs more depth, critical analysis, and academic rigor to be truly insightful.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The search_result looks like this but in the shared_storage we store only AI messages
